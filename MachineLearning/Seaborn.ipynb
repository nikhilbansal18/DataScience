# %% [markdown]
# ### Charts
#
# Line chart - Visualize trends over time
#
# Bar Charts and Heatmaps - Use color or length to compare categories in a dataset
#
# Scatter Plots - Leverage the coordinate plane to explore relationships between variables
#
# Distributions - Create histograms and density plots

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
df = pd.read_csv("/Users/nikhilbansal/Documents/Coding/Python/data/fifa.csv", index_col="Date", parse_dates=True)
df.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
df[df.index=='1993-09-23']

# df.index, and it is not possible to use df['Date'] (which will return an error). 
# This is because when we loaded the dataset, the "Date" column was used to index the rows. 
# We always have to use this special notation to select the indexing column.
# Out:
#              ARG  BRA   ESP  FRA  GER  ITA
# Date
# 1993-09-23  12.0  1.0  14.0  7.0  5.0  2.0

# %%
df.loc[pd.to_datetime(df.Date) == pd.Timestamp('1993.09.23')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-4392c8634df7> in <module>
# ----> 1 df.loc[pd.to_datetime(df.Date) == pd.Timestamp('1993.09.23')]
#
# ~/opt/anaconda3/envs/MLPipeline/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=df)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sns.heatmap(data=df, annot=True)
# Out:
# <AxesSubplot:ylabel='Date'>

# %% [markdown]
# ### Scatter Plot
#
# sns.scatterplot(x=candy_data.sugarpercent, y=candy_data.winpercent)
#
# sns.regplot(x=candy_data.sugarpercent, y=candy_data.winpercent)
#
# sns.scatterplot(x=candy_data.sugarpercent, y=candy_data.winpercent, hue=candy_data.chocolate)
#
# sns.lmplot(x="sugarpercent", y="winpercent", hue="chocolate", data = candy_data)
#
# sns.swarmplot(x=candy_data['chocolate'],y=candy_data['winpercent'])
